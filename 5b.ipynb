# %%
from neural_network import *
from data_prep import *
import matplotlib.pyplot as plt




if __name__ == "__main__":

    net = Network(
        layers = [784,60,60,10],
        max_epoch = 30,
        eta = 0.001,
        func = 'sigmoid',
        is_sqrt_initialize = True,
        is_shuffle = True,
        momentum_type = "momentum"
    )
    training_images,training_labels,test_images,test_labels = data_prep()
    net.fit(training_images,training_labels,test_images,test_labels)
# Out:
# Epoch[0]
# Counter:0
# Accuracy : 	Training :     9.8740	 Test :     9.5800	 Hold out :     9.8100
# Loss     : 	Training :     2.8643	 Test :     2.8659	 Hold out :     2.8512
# Counter:80
# Accuracy : 	Training :    85.3680	 Test :    86.0800	 Hold out :    85.5200
# Loss     : 	Training :     0.5441	 Test :     0.5303	 Hold out :     0.5519
# Counter:160
# Accuracy : 	Training :    89.6760	 Test :    89.9800	 Hold out :    89.6400
# Loss     : 	Training :     0.3556	 Test :     0.3429	 Hold out :     0.3638
# Counter:240
# Accuracy : 	Training :    90.5860	 Test :    91.0900	 Hold out :    90.5100
# Loss     : 	Training :     0.3122	 Test :     0.3124	 Hold out :     0.3198
# Counter:320
# Accuracy : 	Training :    92.1100	 Test :    92.2700	 Hold out :    91.8900
# Loss     : 	Training :     0.2672	 Test :     0.2667	 Hold out :     0.2779
#
# Epoch[1]
# Counter:0
# Accuracy : 	Training :    92.1060	 Test :    92.2600	 Hold out :    92.2500
# Loss     : 	Training :     0.2587	 Test :     0.2569	 Hold out :     0.2497
# Counter:80
# Accuracy : 	Training :    92.3880	 Test :    92.2800	 Hold out :    92.7600
# Loss     : 	Training :     0.2600	 Test :     0.2603	 Hold out :     0.2509
# Counter:160
# Accuracy : 	Training :    93.6480	 Test :    93.4900	 Hold out :    93.6700
# Loss     : 	Training :     0.2174	 Test :     0.2233	 Hold out :     0.2167
# Counter:240
# Accuracy : 	Training :    93.2220	 Test :    93.0900	 Hold out :    93.0500
# Loss     : 	Training :     0.2250	 Test :     0.2399	 Hold out :     0.2277
# Counter:320
# Accuracy : 	Training :    94.0880	 Test :    93.7100	 Hold out :    93.7100
# Loss     : 	Training :     0.1991	 Test :     0.2042	 Hold out :     0.2027
#
# Epoch[2]
# Counter:0
# Accuracy : 	Training :    94.5180	 Test :    94.2100	 Hold out :    94.7200
# Loss     : 	Training :     0.1884	 Test :     0.1982	 Hold out :     0.1769
# Counter:80
# Accuracy : 	Training :    94.9820	 Test :    94.7300	 Hold out :    95.3100
# Loss     : 	Training :     0.1666	 Test :     0.1754	 Hold out :     0.1556
# Counter:160
# Accuracy : 	Training :    94.9980	 Test :    94.4900	 Hold out :    94.9100
# Loss     : 	Training :     0.1697	 Test :     0.1831	 Hold out :     0.1693
# Counter:240
# Accuracy : 	Training :    94.5860	 Test :    94.0300	 Hold out :    94.7100
# Loss     : 	Training :     0.1799	 Test :     0.1964	 Hold out :     0.1757
# Counter:320
# Accuracy : 	Training :    95.4180	 Test :    95.2200	 Hold out :    95.5600
# Loss     : 	Training :     0.1511	 Test :     0.1640	 Hold out :     0.1481
#
# Epoch[3]
# Counter:0
# Accuracy : 	Training :    95.0700	 Test :    94.6300	 Hold out :    94.8100
# Loss     : 	Training :     0.1652	 Test :     0.1817	 Hold out :     0.1692
# Counter:80
# Accuracy : 	Training :    95.2600	 Test :    94.9500	 Hold out :    95.0500
# Loss     : 	Training :     0.1535	 Test :     0.1675	 Hold out :     0.1598
# Counter:160
# Accuracy : 	Training :    95.3020	 Test :    94.8400	 Hold out :    95.0800
# Loss     : 	Training :     0.1527	 Test :     0.1665	 Hold out :     0.1675
# Counter:240
# Accuracy : 	Training :    95.4220	 Test :    95.0100	 Hold out :    95.1800
# Loss     : 	Training :     0.1473	 Test :     0.1618	 Hold out :     0.1615
# Counter:320
# Accuracy : 	Training :    95.7540	 Test :    95.3600	 Hold out :    95.4200
# Loss     : 	Training :     0.1366	 Test :     0.1515	 Hold out :     0.1531
#
# Epoch[4]
# Counter:0
# Accuracy : 	Training :    95.5940	 Test :    95.3600	 Hold out :    95.5500
# Loss     : 	Training :     0.1459	 Test :     0.1612	 Hold out :     0.1492
# Counter:80
# Accuracy : 	Training :    95.8940	 Test :    95.2500	 Hold out :    95.7300
# Loss     : 	Training :     0.1346	 Test :     0.1591	 Hold out :     0.1436
# Counter:160
# Accuracy : 	Training :    95.8980	 Test :    95.3900	 Hold out :    95.6000
# Loss     : 	Training :     0.1394	 Test :     0.1641	 Hold out :     0.1488
# Counter:240
# Accuracy : 	Training :    96.0500	 Test :    95.4000	 Hold out :    95.6700
# Loss     : 	Training :     0.1263	 Test :     0.1521	 Hold out :     0.1392
# Counter:320
# Accuracy : 	Training :    96.4800	 Test :    96.0600	 Hold out :    95.9800
# Loss     : 	Training :     0.1174	 Test :     0.1381	 Hold out :     0.1329
#
# Epoch[5]
# Counter:0
# Accuracy : 	Training :    96.2520	 Test :    95.6700	 Hold out :    96.1500
# Loss     : 	Training :     0.1211	 Test :     0.1426	 Hold out :     0.1260
# Counter:80
# Accuracy : 	Training :    96.7020	 Test :    95.8400	 Hold out :    96.3000
# Loss     : 	Training :     0.1120	 Test :     0.1369	 Hold out :     0.1197
# Counter:160
# Accuracy : 	Training :    96.5680	 Test :    95.8600	 Hold out :    96.2400
# Loss     : 	Training :     0.1116	 Test :     0.1369	 Hold out :     0.1199
# Counter:240
# Accuracy : 	Training :    96.6620	 Test :    95.8400	 Hold out :    96.3200
# Loss     : 	Training :     0.1149	 Test :     0.1391	 Hold out :     0.1233
# Counter:320
# Accuracy : 	Training :    96.2700	 Test :    95.8000	 Hold out :    95.7600
# Loss     : 	Training :     0.1193	 Test :     0.1421	 Hold out :     0.1294
#
# Epoch[6]
# Counter:0
# Accuracy : 	Training :    96.3420	 Test :    95.3300	 Hold out :    96.1200
# Loss     : 	Training :     0.1212	 Test :     0.1503	 Hold out :     0.1211
# Counter:80
# Accuracy : 	Training :    96.4480	 Test :    95.6300	 Hold out :    96.1400
# Loss     : 	Training :     0.1147	 Test :     0.1379	 Hold out :     0.1237
# Counter:160
# Accuracy : 	Training :    96.9640	 Test :    96.2900	 Hold out :    96.6200
# Loss     : 	Training :     0.0991	 Test :     0.1252	 Hold out :     0.1092
# Counter:240
# Accuracy : 	Training :    96.8880	 Test :    96.3700	 Hold out :    96.8300
# Loss     : 	Training :     0.1013	 Test :     0.1312	 Hold out :     0.1052
# Counter:320
# Accuracy : 	Training :    96.8960	 Test :    95.9900	 Hold out :    96.5200
# Loss     : 	Training :     0.1014	 Test :     0.1348	 Hold out :     0.1128
#
# Epoch[7]
# Counter:0
# Accuracy : 	Training :    96.1660	 Test :    95.6300	 Hold out :    95.7900
# Loss     : 	Training :     0.1228	 Test :     0.1453	 Hold out :     0.1322
# Counter:80
# Accuracy : 	Training :    97.0800	 Test :    96.1800	 Hold out :    96.6700
# Loss     : 	Training :     0.0972	 Test :     0.1276	 Hold out :     0.1105
# Counter:160
# Accuracy : 	Training :    96.8260	 Test :    96.3300	 Hold out :    96.4900
# Loss     : 	Training :     0.1012	 Test :     0.1298	 Hold out :     0.1171
# Counter:240
# Accuracy : 	Training :    97.1800	 Test :    96.4400	 Hold out :    96.6800
# Loss     : 	Training :     0.0925	 Test :     0.1166	 Hold out :     0.1082
# Counter:320
# Accuracy : 	Training :    96.8500	 Test :    96.3300	 Hold out :    96.3700
# Loss     : 	Training :     0.1006	 Test :     0.1238	 Hold out :     0.1155
#
# Epoch[8]
# Counter:0
# Accuracy : 	Training :    97.0160	 Test :    96.3400	 Hold out :    97.2100
# Loss     : 	Training :     0.0970	 Test :     0.1263	 Hold out :     0.0959
# Counter:80
# Accuracy : 	Training :    96.2640	 Test :    95.5900	 Hold out :    96.1200
# Loss     : 	Training :     0.1171	 Test :     0.1450	 Hold out :     0.1175
# Counter:160
# Accuracy : 	Training :    97.1100	 Test :    96.3500	 Hold out :    96.9000
# Loss     : 	Training :     0.0939	 Test :     0.1241	 Hold out :     0.0995
# Counter:240
# Accuracy : 	Training :    97.4620	 Test :    96.6800	 Hold out :    96.9700
# Loss     : 	Training :     0.0833	 Test :     0.1173	 Hold out :     0.0965
# Counter:320
# Accuracy : 	Training :    96.8120	 Test :    96.1700	 Hold out :    96.6800
# Loss     : 	Training :     0.1033	 Test :     0.1374	 Hold out :     0.1088
#
# Epoch[9]
# Counter:0
# Accuracy : 	Training :    97.6460	 Test :    96.7800	 Hold out :    97.5800
# Loss     : 	Training :     0.0799	 Test :     0.1101	 Hold out :     0.0784
# Counter:80
# Accuracy : 	Training :    97.0200	 Test :    96.3900	 Hold out :    97.1700
# Loss     : 	Training :     0.0936	 Test :     0.1211	 Hold out :     0.0869
# Counter:160
# Accuracy : 	Training :    97.2120	 Test :    96.1200	 Hold out :    97.1500
# Loss     : 	Training :     0.0923	 Test :     0.1240	 Hold out :     0.0969
# Counter:240
# Accuracy : 	Training :    97.3480	 Test :    96.4500	 Hold out :    97.2600
# Loss     : 	Training :     0.0859	 Test :     0.1186	 Hold out :     0.0894
# Counter:320
# Accuracy : 	Training :    97.3560	 Test :    96.4000	 Hold out :    97.2900
# Loss     : 	Training :     0.0831	 Test :     0.1217	 Hold out :     0.0886
# Epoch[10]
# Counter:0
# Accuracy : 	Training :    97.5980	 Test :    96.5900	 Hold out :    97.5300
# Loss     : 	Training :     0.0780	 Test :     0.1134	 Hold out :     0.0747
# Counter:80
# Accuracy : 	Training :    97.4540	 Test :    96.5700	 Hold out :    97.2000
# Loss     : 	Training :     0.0814	 Test :     0.1171	 Hold out :     0.0820
# Counter:160
# Accuracy : 	Training :    97.8240	 Test :    96.8400	 Hold out :    97.6400
# Loss     : 	Training :     0.0710	 Test :     0.1080	 Hold out :     0.0742
# Counter:240
# Accuracy : 	Training :    97.3580	 Test :    96.3600	 Hold out :    97.0600
# Loss     : 	Training :     0.0850	 Test :     0.1242	 Hold out :     0.0904
# Counter:320
# Accuracy : 	Training :    97.4320	 Test :    96.1800	 Hold out :    96.9400
# Loss     : 	Training :     0.0846	 Test :     0.1261	 Hold out :     0.0960
#
# Epoch[11]
# Counter:0
# Accuracy : 	Training :    97.6780	 Test :    96.7600	 Hold out :    97.8700
# Loss     : 	Training :     0.0751	 Test :     0.1074	 Hold out :     0.0709
# Counter:80
# Accuracy : 	Training :    97.7960	 Test :    96.6200	 Hold out :    97.8400
# Loss     : 	Training :     0.0723	 Test :     0.1118	 Hold out :     0.0701
# Counter:160
# Accuracy : 	Training :    97.3700	 Test :    96.2500	 Hold out :    97.1300
# Loss     : 	Training :     0.0826	 Test :     0.1204	 Hold out :     0.0885
# Counter:240
# Accuracy : 	Training :    97.3560	 Test :    96.2400	 Hold out :    97.0700
# Loss     : 	Training :     0.0835	 Test :     0.1177	 Hold out :     0.0929
# Counter:320
# Accuracy : 	Training :    97.4600	 Test :    96.3700	 Hold out :    97.4600
# Loss     : 	Training :     0.0822	 Test :     0.1198	 Hold out :     0.0836
#
# Epoch[12]
# Counter:0
# Accuracy : 	Training :    97.8680	 Test :    96.5000	 Hold out :    97.6600
# Loss     : 	Training :     0.0696	 Test :     0.1171	 Hold out :     0.0697
# Counter:80
# Accuracy : 	Training :    97.8280	 Test :    96.6200	 Hold out :    97.7100
# Loss     : 	Training :     0.0725	 Test :     0.1104	 Hold out :     0.0770
# Counter:160
# Accuracy : 	Training :    97.5400	 Test :    96.4600	 Hold out :    97.2200
# Loss     : 	Training :     0.0772	 Test :     0.1141	 Hold out :     0.0891
# Counter:240
# Accuracy : 	Training :    97.5300	 Test :    96.4900	 Hold out :    97.2400
# Loss     : 	Training :     0.0775	 Test :     0.1220	 Hold out :     0.0873
# Counter:320
# Accuracy : 	Training :    96.9180	 Test :    95.8500	 Hold out :    96.6600
# Loss     : 	Training :     0.0951	 Test :     0.1343	 Hold out :     0.1040
#
# Epoch[13]
# Counter:0
# Accuracy : 	Training :    97.3020	 Test :    96.0500	 Hold out :    97.3400
# Loss     : 	Training :     0.0831	 Test :     0.1252	 Hold out :     0.0768
# Counter:80
# Accuracy : 	Training :    98.0320	 Test :    96.8400	 Hold out :    98.0300
# Loss     : 	Training :     0.0655	 Test :     0.1074	 Hold out :     0.0632
# Counter:160
# Accuracy : 	Training :    97.9760	 Test :    96.6600	 Hold out :    97.9900
# Loss     : 	Training :     0.0660	 Test :     0.1105	 Hold out :     0.0680
# Counter:240
# Accuracy : 	Training :    97.7260	 Test :    96.4700	 Hold out :    97.5900
# Loss     : 	Training :     0.0723	 Test :     0.1198	 Hold out :     0.0725
# Counter:320
# Accuracy : 	Training :    97.5440	 Test :    96.4000	 Hold out :    97.4700
# Loss     : 	Training :     0.0776	 Test :     0.1193	 Hold out :     0.0825
#
# Epoch[14]
# Counter:0
# Accuracy : 	Training :    97.9340	 Test :    96.7300	 Hold out :    98.3300
# Loss     : 	Training :     0.0656	 Test :     0.1154	 Hold out :     0.0558
# Counter:80
# Accuracy : 	Training :    97.8300	 Test :    96.8000	 Hold out :    98.0900
# Loss     : 	Training :     0.0684	 Test :     0.1125	 Hold out :     0.0598
# Counter:160
# Accuracy : 	Training :    98.0520	 Test :    96.9400	 Hold out :    98.1000
# Loss     : 	Training :     0.0619	 Test :     0.1058	 Hold out :     0.0579
# Counter:240
# Accuracy : 	Training :    98.1540	 Test :    96.8400	 Hold out :    98.2100
# Loss     : 	Training :     0.0607	 Test :     0.1067	 Hold out :     0.0594
# Counter:320
# Accuracy : 	Training :    97.4900	 Test :    96.4200	 Hold out :    97.5100
# Loss     : 	Training :     0.0767	 Test :     0.1239	 Hold out :     0.0730
#
# Epoch[15]
# Counter:0
# Accuracy : 	Training :    98.1040	 Test :    96.8100	 Hold out :    98.1300
# Loss     : 	Training :     0.0593	 Test :     0.1056	 Hold out :     0.0592
# Counter:80
# Accuracy : 	Training :    98.1780	 Test :    96.5000	 Hold out :    97.8900
# Loss     : 	Training :     0.0594	 Test :     0.1106	 Hold out :     0.0634
# Counter:160
# Accuracy : 	Training :    98.2700	 Test :    96.8900	 Hold out :    98.1800
# Loss     : 	Training :     0.0554	 Test :     0.1059	 Hold out :     0.0587
# Counter:240
# Accuracy : 	Training :    97.8380	 Test :    96.3600	 Hold out :    97.5400
# Loss     : 	Training :     0.0685	 Test :     0.1175	 Hold out :     0.0744
# Counter:320
# Accuracy : 	Training :    98.1360	 Test :    96.5800	 Hold out :    97.7200
# Loss     : 	Training :     0.0586	 Test :     0.1045	 Hold out :     0.0692
#
# Epoch[16]
# Counter:0
# Accuracy : 	Training :    98.1320	 Test :    96.9300	 Hold out :    98.0900
# Loss     : 	Training :     0.0593	 Test :     0.1068	 Hold out :     0.0608
# Counter:80
# Accuracy : 	Training :    97.8080	 Test :    96.3000	 Hold out :    97.7200
# Loss     : 	Training :     0.0661	 Test :     0.1181	 Hold out :     0.0700
# Counter:160
# Accuracy : 	Training :    98.1060	 Test :    96.7100	 Hold out :    98.0100
# Loss     : 	Training :     0.0576	 Test :     0.1124	 Hold out :     0.0642
# Counter:240
# Accuracy : 	Training :    98.1300	 Test :    96.8000	 Hold out :    97.9000
# Loss     : 	Training :     0.0587	 Test :     0.1093	 Hold out :     0.0681
# Counter:320
# Accuracy : 	Training :    98.4860	 Test :    97.0600	 Hold out :    98.3500
# Loss     : 	Training :     0.0482	 Test :     0.0945	 Hold out :     0.0551
#
# Epoch[17]
# Counter:0
# Accuracy : 	Training :    97.5380	 Test :    96.2800	 Hold out :    97.7200
# Loss     : 	Training :     0.0767	 Test :     0.1338	 Hold out :     0.0769
# Counter:80
# Accuracy : 	Training :    98.5600	 Test :    96.9400	 Hold out :    98.5600
# Loss     : 	Training :     0.0459	 Test :     0.1013	 Hold out :     0.0506
# Counter:160
# Accuracy : 	Training :    98.1900	 Test :    96.8200	 Hold out :    98.0100
# Loss     : 	Training :     0.0553	 Test :     0.1093	 Hold out :     0.0642
# Counter:240
# Accuracy : 	Training :    98.4020	 Test :    96.8600	 Hold out :    98.0600
# Loss     : 	Training :     0.0503	 Test :     0.1011	 Hold out :     0.0616
# Counter:320
# Accuracy : 	Training :    98.3020	 Test :    96.7600	 Hold out :    98.2000
# Loss     : 	Training :     0.0525	 Test :     0.1031	 Hold out :     0.0598
#
# Epoch[18]
# Counter:0
# Accuracy : 	Training :    97.8640	 Test :    96.7500	 Hold out :    97.8700
# Loss     : 	Training :     0.0650	 Test :     0.1105	 Hold out :     0.0658
# Counter:80
# Accuracy : 	Training :    98.3500	 Test :    96.7100	 Hold out :    98.1600
# Loss     : 	Training :     0.0533	 Test :     0.1077	 Hold out :     0.0585
# Counter:160
# Accuracy : 	Training :    97.1560	 Test :    95.8300	 Hold out :    96.9000
# Loss     : 	Training :     0.0839	 Test :     0.1392	 Hold out :     0.0936
# Counter:240
# Accuracy : 	Training :    98.3160	 Test :    96.9000	 Hold out :    98.0500
# Loss     : 	Training :     0.0523	 Test :     0.1081	 Hold out :     0.0601
# Counter:320
# Accuracy : 	Training :    98.3320	 Test :    96.9000	 Hold out :    98.0800
# Loss     : 	Training :     0.0516	 Test :     0.1033	 Hold out :     0.0606
#
# Epoch[19]
# Counter:0
# Accuracy : 	Training :    98.3300	 Test :    96.7900	 Hold out :    98.3700
# Loss     : 	Training :     0.0528	 Test :     0.1115	 Hold out :     0.0496
# Counter:80
# Accuracy : 	Training :    98.5600	 Test :    96.9600	 Hold out :    98.4700
# Loss     : 	Training :     0.0459	 Test :     0.1016	 Hold out :     0.0461
# Counter:160
# Accuracy : 	Training :    98.4620	 Test :    96.8100	 Hold out :    98.3200
# Loss     : 	Training :     0.0482	 Test :     0.1056	 Hold out :     0.0503
# Counter:240
# Accuracy : 	Training :    98.5600	 Test :    97.0400	 Hold out :    98.3200
# Loss     : 	Training :     0.0467	 Test :     0.1028	 Hold out :     0.0492
# Counter:320
# Accuracy : 	Training :    98.5880	 Test :    96.8600	 Hold out :    98.3100
# Loss     : 	Training :     0.0452	 Test :     0.1043	 Hold out :     0.0520
# Epoch[20]
# Counter:0
# Accuracy : 	Training :    96.4120	 Test :    95.1900	 Hold out :    96.5100
# Loss     : 	Training :     0.1069	 Test :     0.1623	 Hold out :     0.0974
# Counter:80
# Accuracy : 	Training :    98.3340	 Test :    96.8700	 Hold out :    98.1800
# Loss     : 	Training :     0.0522	 Test :     0.1092	 Hold out :     0.0526
# Counter:160
# Accuracy : 	Training :    98.0340	 Test :    96.4200	 Hold out :    97.9400
# Loss     : 	Training :     0.0613	 Test :     0.1162	 Hold out :     0.0638
# Counter:240
# Accuracy : 	Training :    98.2620	 Test :    96.9600	 Hold out :    97.9600
# Loss     : 	Training :     0.0522	 Test :     0.1072	 Hold out :     0.0599
# Counter:320
# Accuracy : 	Training :    98.2360	 Test :    96.6000	 Hold out :    97.7700
# Loss     : 	Training :     0.0572	 Test :     0.1162	 Hold out :     0.0662
#
# Epoch[21]
# Counter:0
# Accuracy : 	Training :    98.5680	 Test :    96.7800	 Hold out :    98.5000
# Loss     : 	Training :     0.0471	 Test :     0.1061	 Hold out :     0.0496
# Counter:80
# Accuracy : 	Training :    98.5600	 Test :    97.0600	 Hold out :    98.4100
# Loss     : 	Training :     0.0451	 Test :     0.1042	 Hold out :     0.0491
# Counter:160
# Accuracy : 	Training :    98.3740	 Test :    96.8200	 Hold out :    98.1100
# Loss     : 	Training :     0.0513	 Test :     0.1085	 Hold out :     0.0569
# Counter:240
# Accuracy : 	Training :    98.0100	 Test :    96.4700	 Hold out :    97.7600
# Loss     : 	Training :     0.0598	 Test :     0.1263	 Hold out :     0.0681
# Counter:320
# Accuracy : 	Training :    98.7360	 Test :    96.9000	 Hold out :    98.3400
# Loss     : 	Training :     0.0412	 Test :     0.1005	 Hold out :     0.0521
#
# Epoch[22]
# Counter:0
# Accuracy : 	Training :    98.5920	 Test :    97.0800	 Hold out :    98.7800
# Loss     : 	Training :     0.0440	 Test :     0.1040	 Hold out :     0.0398
# Counter:80
# Accuracy : 	Training :    98.3020	 Test :    96.6400	 Hold out :    98.4500
# Loss     : 	Training :     0.0522	 Test :     0.1113	 Hold out :     0.0469
# Counter:160
# Accuracy : 	Training :    98.6220	 Test :    96.8400	 Hold out :    98.8000
# Loss     : 	Training :     0.0432	 Test :     0.1044	 Hold out :     0.0402
# Counter:240
# Accuracy : 	Training :    98.8320	 Test :    97.1200	 Hold out :    98.7900
# Loss     : 	Training :     0.0379	 Test :     0.1032	 Hold out :     0.0384
# Counter:320
# Accuracy : 	Training :    98.4040	 Test :    96.6300	 Hold out :    98.5200
# Loss     : 	Training :     0.0482	 Test :     0.1102	 Hold out :     0.0460
#
# Epoch[23]
# Counter:0
# Accuracy : 	Training :    98.4440	 Test :    96.8300	 Hold out :    98.3500
# Loss     : 	Training :     0.0469	 Test :     0.1108	 Hold out :     0.0523
# Counter:80
# Accuracy : 	Training :    98.7580	 Test :    96.8400	 Hold out :    98.5300
# Loss     : 	Training :     0.0388	 Test :     0.1051	 Hold out :     0.0482
# Counter:160
# Accuracy : 	Training :    98.9780	 Test :    96.9700	 Hold out :    98.8000
# Loss     : 	Training :     0.0338	 Test :     0.1014	 Hold out :     0.0440
# Counter:240
# Accuracy : 	Training :    99.0600	 Test :    97.2000	 Hold out :    98.8700
# Loss     : 	Training :     0.0314	 Test :     0.0978	 Hold out :     0.0419
# Counter:320
# Accuracy : 	Training :    98.2500	 Test :    96.4400	 Hold out :    98.2200
# Loss     : 	Training :     0.0513	 Test :     0.1174	 Hold out :     0.0599
#
# Epoch[24]
# Counter:0
# Accuracy : 	Training :    98.7000	 Test :    97.0800	 Hold out :    98.8600
# Loss     : 	Training :     0.0400	 Test :     0.1020	 Hold out :     0.0357
# Counter:80
# Accuracy : 	Training :    98.5660	 Test :    96.9800	 Hold out :    98.7200
# Loss     : 	Training :     0.0446	 Test :     0.1103	 Hold out :     0.0386
# Counter:160
# Accuracy : 	Training :    98.7460	 Test :    96.9800	 Hold out :    98.8400
# Loss     : 	Training :     0.0389	 Test :     0.1061	 Hold out :     0.0383
# Counter:240
# Accuracy : 	Training :    98.5440	 Test :    96.8200	 Hold out :    98.3400
# Loss     : 	Training :     0.0459	 Test :     0.1130	 Hold out :     0.0506
# Counter:320
# Accuracy : 	Training :    98.9860	 Test :    97.1100	 Hold out :    98.9900
# Loss     : 	Training :     0.0331	 Test :     0.1003	 Hold out :     0.0328
#
# Epoch[25]
# Counter:0
# Accuracy : 	Training :    98.7420	 Test :    97.0500	 Hold out :    98.9700
# Loss     : 	Training :     0.0395	 Test :     0.1052	 Hold out :     0.0342
# Counter:80
# Accuracy : 	Training :    98.8020	 Test :    97.0100	 Hold out :    98.9300
# Loss     : 	Training :     0.0375	 Test :     0.1062	 Hold out :     0.0325
# Counter:160
# Accuracy : 	Training :    98.9700	 Test :    97.1400	 Hold out :    99.0500
# Loss     : 	Training :     0.0329	 Test :     0.0993	 Hold out :     0.0313
# Counter:240
# Accuracy : 	Training :    98.7280	 Test :    96.8600	 Hold out :    98.5200
# Loss     : 	Training :     0.0411	 Test :     0.1109	 Hold out :     0.0439
# Counter:320
# Accuracy : 	Training :    98.7100	 Test :    96.9400	 Hold out :    98.5400
# Loss     : 	Training :     0.0406	 Test :     0.1101	 Hold out :     0.0440
#
# Epoch[26]
# Counter:0
# Accuracy : 	Training :    98.2380	 Test :    96.6000	 Hold out :    98.3500
# Loss     : 	Training :     0.0511	 Test :     0.1199	 Hold out :     0.0527
# Counter:80
# Accuracy : 	Training :    98.7000	 Test :    96.9600	 Hold out :    98.5700
# Loss     : 	Training :     0.0392	 Test :     0.1101	 Hold out :     0.0458
# Counter:160
# Accuracy : 	Training :    98.6480	 Test :    96.7900	 Hold out :    98.3100
# Loss     : 	Training :     0.0418	 Test :     0.1124	 Hold out :     0.0516
# Counter:240
# Accuracy : 	Training :    98.7340	 Test :    96.7000	 Hold out :    98.3800
# Loss     : 	Training :     0.0393	 Test :     0.1139	 Hold out :     0.0497
# Counter:320
# Accuracy : 	Training :    98.4460	 Test :    96.7900	 Hold out :    98.2000
# Loss     : 	Training :     0.0460	 Test :     0.1103	 Hold out :     0.0552
#
# Epoch[27]
# Counter:0
# Accuracy : 	Training :    98.4940	 Test :    96.8500	 Hold out :    98.4600
# Loss     : 	Training :     0.0461	 Test :     0.1151	 Hold out :     0.0463
# Counter:80
# Accuracy : 	Training :    98.7540	 Test :    97.0100	 Hold out :    98.7900
# Loss     : 	Training :     0.0389	 Test :     0.1058	 Hold out :     0.0391
# Counter:160
# Accuracy : 	Training :    98.6000	 Test :    96.8600	 Hold out :    98.5300
# Loss     : 	Training :     0.0430	 Test :     0.1177	 Hold out :     0.0421
# Counter:240
# Accuracy : 	Training :    99.1660	 Test :    97.1600	 Hold out :    98.8600
# Loss     : 	Training :     0.0294	 Test :     0.1045	 Hold out :     0.0325
# Counter:320
# Accuracy : 	Training :    98.9520	 Test :    96.9300	 Hold out :    98.8000
# Loss     : 	Training :     0.0334	 Test :     0.1093	 Hold out :     0.0379
#
# Epoch[28]
# Counter:0
# Accuracy : 	Training :    98.7400	 Test :    96.7500	 Hold out :    98.6500
# Loss     : 	Training :     0.0388	 Test :     0.1201	 Hold out :     0.0434
# Counter:80
# Accuracy : 	Training :    98.7460	 Test :    96.6100	 Hold out :    98.4700
# Loss     : 	Training :     0.0395	 Test :     0.1176	 Hold out :     0.0465
# Counter:160
# Accuracy : 	Training :    99.0140	 Test :    97.0200	 Hold out :    98.7200
# Loss     : 	Training :     0.0309	 Test :     0.1064	 Hold out :     0.0377
# Counter:240
# Accuracy : 	Training :    99.0200	 Test :    97.0300	 Hold out :    98.8700
# Loss     : 	Training :     0.0324	 Test :     0.1055	 Hold out :     0.0383
# Counter:320
# Accuracy : 	Training :    99.1100	 Test :    96.9800	 Hold out :    98.8100
# Loss     : 	Training :     0.0286	 Test :     0.1022	 Hold out :     0.0383
#
# Epoch[29]
# Counter:0
# Accuracy : 	Training :    99.1360	 Test :    97.2100	 Hold out :    99.1000
# Loss     : 	Training :     0.0295	 Test :     0.0993	 Hold out :     0.0308
# Counter:80
# Accuracy : 	Training :    99.1540	 Test :    96.9000	 Hold out :    99.0300
# Loss     : 	Training :     0.0281	 Test :     0.1035	 Hold out :     0.0321
# Counter:160
# Accuracy : 	Training :    98.6960	 Test :    96.7800	 Hold out :    98.4500
# Loss     : 	Training :     0.0411	 Test :     0.1174	 Hold out :     0.0462
# Counter:240
# Accuracy : 	Training :    99.0840	 Test :    97.2100	 Hold out :    98.7600
# Loss     : 	Training :     0.0289	 Test :     0.1068	 Hold out :     0.0364
# Counter:320
# Accuracy : 	Training :    99.1140	 Test :    97.1500	 Hold out :    98.8000
# Loss     : 	Training :     0.0286	 Test :     0.0968	 Hold out :     0.0390

# %%
plt.figure
plt.plot(np.arange(0,len(net.records["loss"]["training"])),net.records["loss"]["training"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["test"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["hold_out"])
plt.gca().set_title("Loss over training")
plt.gca().legend(["Training","Test","Hold out"])
plt.xlabel("Training")
plt.ylabel("Loss")
plt.grid()
plt.savefig("./img/loss_5b",dpi=300)
plt.show()


plt.figure()
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])),net.records["accuracy"]["training"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["test"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["hold_out"])
plt.gca().set_title("Accuracy over training")
plt.gca().legend(["Training","Test","Hold out"])
plt.xlabel("Training")
plt.ylabel("Accuracy")
plt.gca().set_yticks([0,20,40,60,80,90,98])
plt.grid()
plt.savefig("./img/acc_5b",dpi=300)
plt.show()

# %%
import pickle
with open("./pickle_data/5b.dat","wb") as f:
    net.data = None
    pickle.dump(net, f)
