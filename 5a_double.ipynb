# %%
from neural_network import *
from data_prep import *
import matplotlib.pyplot as plt




if __name__ == "__main__":

    net = Network(
        layers = [784,128,10],
        max_epoch = 30,
        eta = 0.001,
        func = 'sigmoid',
        is_sqrt_initialize = True,
        is_shuffle = True,
        momentum_type = "momentum"
    )
    training_images,training_labels,test_images,test_labels = data_prep()
    net.fit(training_images,training_labels,test_images,test_labels)
# Out:
# Epoch[0]
# Counter:0
# Accuracy : 	Training :     8.3360	 Test :     7.7800	 Hold out :     8.3300
# Loss     : 	Training :     3.9024	 Test :     3.9303	 Hold out :     3.8897
# Counter:80
# Accuracy : 	Training :    88.7740	 Test :    89.3900	 Hold out :    89.0000
# Loss     : 	Training :     0.3795	 Test :     0.3634	 Hold out :     0.3944
# Counter:160
# Accuracy : 	Training :    91.0520	 Test :    91.2300	 Hold out :    90.7100
# Loss     : 	Training :     0.3058	 Test :     0.3051	 Hold out :     0.3192
# Counter:240
# Accuracy : 	Training :    91.8520	 Test :    92.1100	 Hold out :    91.6100
# Loss     : 	Training :     0.2684	 Test :     0.2683	 Hold out :     0.2842
# Counter:320
# Accuracy : 	Training :    92.3620	 Test :    92.4100	 Hold out :    91.8300
# Loss     : 	Training :     0.2586	 Test :     0.2561	 Hold out :     0.2726
#
# Epoch[1]
# Counter:0
# Accuracy : 	Training :    93.2760	 Test :    93.3200	 Hold out :    92.8200
# Loss     : 	Training :     0.2269	 Test :     0.2218	 Hold out :     0.2276
# Counter:80
# Accuracy : 	Training :    93.4420	 Test :    93.1300	 Hold out :    93.0200
# Loss     : 	Training :     0.2283	 Test :     0.2318	 Hold out :     0.2304
# Counter:160
# Accuracy : 	Training :    93.3440	 Test :    92.8800	 Hold out :    92.8900
# Loss     : 	Training :     0.2178	 Test :     0.2293	 Hold out :     0.2257
# Counter:240
# Accuracy : 	Training :    94.2100	 Test :    94.0600	 Hold out :    93.4500
# Loss     : 	Training :     0.1926	 Test :     0.1977	 Hold out :     0.2053
# Counter:320
# Accuracy : 	Training :    95.2060	 Test :    94.9100	 Hold out :    94.4400
# Loss     : 	Training :     0.1618	 Test :     0.1692	 Hold out :     0.1720
#
# Epoch[2]
# Counter:0
# Accuracy : 	Training :    94.7740	 Test :    94.6000	 Hold out :    94.9300
# Loss     : 	Training :     0.1717	 Test :     0.1776	 Hold out :     0.1660
# Counter:80
# Accuracy : 	Training :    95.4780	 Test :    95.1600	 Hold out :    95.2700
# Loss     : 	Training :     0.1586	 Test :     0.1642	 Hold out :     0.1617
# Counter:160
# Accuracy : 	Training :    95.0580	 Test :    94.9300	 Hold out :    95.0900
# Loss     : 	Training :     0.1628	 Test :     0.1668	 Hold out :     0.1617
# Counter:240
# Accuracy : 	Training :    95.4380	 Test :    95.0500	 Hold out :    95.3900
# Loss     : 	Training :     0.1524	 Test :     0.1650	 Hold out :     0.1589
# Counter:320
# Accuracy : 	Training :    95.2620	 Test :    94.7600	 Hold out :    94.8900
# Loss     : 	Training :     0.1569	 Test :     0.1697	 Hold out :     0.1601
#
# Epoch[3]
# Counter:0
# Accuracy : 	Training :    96.0040	 Test :    95.5800	 Hold out :    95.7400
# Loss     : 	Training :     0.1389	 Test :     0.1479	 Hold out :     0.1492
# Counter:80
# Accuracy : 	Training :    96.5520	 Test :    96.1500	 Hold out :    96.3500
# Loss     : 	Training :     0.1173	 Test :     0.1276	 Hold out :     0.1284
# Counter:160
# Accuracy : 	Training :    95.9280	 Test :    95.4400	 Hold out :    95.6200
# Loss     : 	Training :     0.1340	 Test :     0.1504	 Hold out :     0.1448
# Counter:240
# Accuracy : 	Training :    96.2400	 Test :    95.6600	 Hold out :    95.7500
# Loss     : 	Training :     0.1232	 Test :     0.1384	 Hold out :     0.1417
# Counter:320
# Accuracy : 	Training :    96.1860	 Test :    95.7600	 Hold out :    95.5800
# Loss     : 	Training :     0.1252	 Test :     0.1405	 Hold out :     0.1438
#
# Epoch[4]
# Counter:0
# Accuracy : 	Training :    96.1700	 Test :    95.7100	 Hold out :    95.7700
# Loss     : 	Training :     0.1247	 Test :     0.1447	 Hold out :     0.1307
# Counter:80
# Accuracy : 	Training :    96.6980	 Test :    96.3800	 Hold out :    96.3500
# Loss     : 	Training :     0.1083	 Test :     0.1277	 Hold out :     0.1201
# Counter:160
# Accuracy : 	Training :    96.5040	 Test :    95.8600	 Hold out :    96.2100
# Loss     : 	Training :     0.1136	 Test :     0.1348	 Hold out :     0.1299
# Counter:240
# Accuracy : 	Training :    96.5420	 Test :    96.1600	 Hold out :    96.1400
# Loss     : 	Training :     0.1101	 Test :     0.1320	 Hold out :     0.1247
# Counter:320
# Accuracy : 	Training :    96.7600	 Test :    96.1000	 Hold out :    96.2200
# Loss     : 	Training :     0.1042	 Test :     0.1237	 Hold out :     0.1242
#
# Epoch[5]
# Counter:0
# Accuracy : 	Training :    96.5760	 Test :    95.9200	 Hold out :    96.7000
# Loss     : 	Training :     0.1117	 Test :     0.1355	 Hold out :     0.1074
# Counter:80
# Accuracy : 	Training :    97.0340	 Test :    96.2300	 Hold out :    97.0300
# Loss     : 	Training :     0.0983	 Test :     0.1260	 Hold out :     0.1002
# Counter:160
# Accuracy : 	Training :    96.5500	 Test :    95.9200	 Hold out :    96.4700
# Loss     : 	Training :     0.1133	 Test :     0.1330	 Hold out :     0.1163
# Counter:240
# Accuracy : 	Training :    96.4500	 Test :    95.7700	 Hold out :    96.0600
# Loss     : 	Training :     0.1181	 Test :     0.1437	 Hold out :     0.1232
# Counter:320
# Accuracy : 	Training :    97.3160	 Test :    96.4100	 Hold out :    97.2100
# Loss     : 	Training :     0.0887	 Test :     0.1145	 Hold out :     0.0958
#
# Epoch[6]
# Counter:0
# Accuracy : 	Training :    97.0800	 Test :    96.1700	 Hold out :    97.2100
# Loss     : 	Training :     0.0948	 Test :     0.1191	 Hold out :     0.0945
# Counter:80
# Accuracy : 	Training :    97.3920	 Test :    96.4400	 Hold out :    97.0400
# Loss     : 	Training :     0.0888	 Test :     0.1162	 Hold out :     0.0952
# Counter:160
# Accuracy : 	Training :    97.2420	 Test :    96.3100	 Hold out :    96.8600
# Loss     : 	Training :     0.0900	 Test :     0.1211	 Hold out :     0.1006
# Counter:240
# Accuracy : 	Training :    97.1760	 Test :    96.1900	 Hold out :    96.9500
# Loss     : 	Training :     0.0922	 Test :     0.1228	 Hold out :     0.1009
# Counter:320
# Accuracy : 	Training :    97.0220	 Test :    96.2700	 Hold out :    96.8200
# Loss     : 	Training :     0.0968	 Test :     0.1264	 Hold out :     0.1083
#
# Epoch[7]
# Counter:0
# Accuracy : 	Training :    97.3860	 Test :    96.3200	 Hold out :    97.2600
# Loss     : 	Training :     0.0864	 Test :     0.1215	 Hold out :     0.0929
# Counter:80
# Accuracy : 	Training :    97.5760	 Test :    96.3100	 Hold out :    97.2700
# Loss     : 	Training :     0.0810	 Test :     0.1136	 Hold out :     0.0856
# Counter:160
# Accuracy : 	Training :    97.5040	 Test :    96.4500	 Hold out :    97.0900
# Loss     : 	Training :     0.0848	 Test :     0.1158	 Hold out :     0.0941
# Counter:240
# Accuracy : 	Training :    97.7780	 Test :    96.6700	 Hold out :    97.2900
# Loss     : 	Training :     0.0765	 Test :     0.1081	 Hold out :     0.0871
# Counter:320
# Accuracy : 	Training :    97.8020	 Test :    96.6400	 Hold out :    97.2800
# Loss     : 	Training :     0.0771	 Test :     0.1140	 Hold out :     0.0877
#
# Epoch[8]
# Counter:0
# Accuracy : 	Training :    97.2440	 Test :    96.3300	 Hold out :    97.4100
# Loss     : 	Training :     0.0879	 Test :     0.1191	 Hold out :     0.0868
# Counter:80
# Accuracy : 	Training :    97.7420	 Test :    96.6900	 Hold out :    97.6600
# Loss     : 	Training :     0.0743	 Test :     0.1050	 Hold out :     0.0776
# Counter:160
# Accuracy : 	Training :    97.0940	 Test :    96.1600	 Hold out :    97.1200
# Loss     : 	Training :     0.0911	 Test :     0.1217	 Hold out :     0.0970
# Counter:240
# Accuracy : 	Training :    97.7240	 Test :    96.6100	 Hold out :    97.4900
# Loss     : 	Training :     0.0753	 Test :     0.1083	 Hold out :     0.0836
# Counter:320
# Accuracy : 	Training :    97.5380	 Test :    96.5200	 Hold out :    97.4700
# Loss     : 	Training :     0.0791	 Test :     0.1138	 Hold out :     0.0867
#
# Epoch[9]
# Counter:0
# Accuracy : 	Training :    97.4620	 Test :    96.6000	 Hold out :    97.9200
# Loss     : 	Training :     0.0790	 Test :     0.1097	 Hold out :     0.0738
# Counter:80
# Accuracy : 	Training :    97.3620	 Test :    96.5100	 Hold out :    97.4900
# Loss     : 	Training :     0.0817	 Test :     0.1150	 Hold out :     0.0826
# Counter:160
# Accuracy : 	Training :    97.4460	 Test :    96.2700	 Hold out :    97.3700
# Loss     : 	Training :     0.0803	 Test :     0.1228	 Hold out :     0.0819
# Counter:240
# Accuracy : 	Training :    98.0200	 Test :    97.0100	 Hold out :    97.9300
# Loss     : 	Training :     0.0667	 Test :     0.1001	 Hold out :     0.0705
# Counter:320
# Accuracy : 	Training :    97.8000	 Test :    96.7000	 Hold out :    97.8900
# Loss     : 	Training :     0.0694	 Test :     0.1063	 Hold out :     0.0694
# Epoch[10]
# Counter:0
# Accuracy : 	Training :    97.3900	 Test :    96.2400	 Hold out :    97.4400
# Loss     : 	Training :     0.0813	 Test :     0.1193	 Hold out :     0.0785
# Counter:80
# Accuracy : 	Training :    98.1080	 Test :    96.9000	 Hold out :    98.1400
# Loss     : 	Training :     0.0612	 Test :     0.1020	 Hold out :     0.0611
# Counter:160
# Accuracy : 	Training :    98.1880	 Test :    96.8400	 Hold out :    98.1600
# Loss     : 	Training :     0.0597	 Test :     0.0995	 Hold out :     0.0610
# Counter:240
# Accuracy : 	Training :    98.2720	 Test :    96.9200	 Hold out :    98.0800
# Loss     : 	Training :     0.0608	 Test :     0.0990	 Hold out :     0.0655
# Counter:320
# Accuracy : 	Training :    98.1160	 Test :    96.7300	 Hold out :    97.6600
# Loss     : 	Training :     0.0619	 Test :     0.1053	 Hold out :     0.0734
#
# Epoch[11]
# Counter:0
# Accuracy : 	Training :    98.1380	 Test :    96.9200	 Hold out :    98.1400
# Loss     : 	Training :     0.0601	 Test :     0.0993	 Hold out :     0.0620
# Counter:80
# Accuracy : 	Training :    98.3860	 Test :    96.9700	 Hold out :    98.1600
# Loss     : 	Training :     0.0565	 Test :     0.0983	 Hold out :     0.0626
# Counter:160
# Accuracy : 	Training :    98.1680	 Test :    96.8900	 Hold out :    97.9300
# Loss     : 	Training :     0.0585	 Test :     0.1020	 Hold out :     0.0672
# Counter:240
# Accuracy : 	Training :    97.9620	 Test :    96.7000	 Hold out :    97.8500
# Loss     : 	Training :     0.0636	 Test :     0.1067	 Hold out :     0.0720
# Counter:320
# Accuracy : 	Training :    98.1800	 Test :    96.8800	 Hold out :    97.7300
# Loss     : 	Training :     0.0586	 Test :     0.1002	 Hold out :     0.0705
#
# Epoch[12]
# Counter:0
# Accuracy : 	Training :    98.1420	 Test :    96.8400	 Hold out :    97.9700
# Loss     : 	Training :     0.0605	 Test :     0.1022	 Hold out :     0.0636
# Counter:80
# Accuracy : 	Training :    98.1320	 Test :    96.8700	 Hold out :    97.8800
# Loss     : 	Training :     0.0611	 Test :     0.1018	 Hold out :     0.0664
# Counter:160
# Accuracy : 	Training :    98.3260	 Test :    96.8300	 Hold out :    98.0600
# Loss     : 	Training :     0.0550	 Test :     0.1005	 Hold out :     0.0618
# Counter:240
# Accuracy : 	Training :    98.2060	 Test :    96.8200	 Hold out :    97.6600
# Loss     : 	Training :     0.0588	 Test :     0.1063	 Hold out :     0.0708
# Counter:320
# Accuracy : 	Training :    98.1440	 Test :    96.7700	 Hold out :    97.5800
# Loss     : 	Training :     0.0592	 Test :     0.1067	 Hold out :     0.0715
#
# Epoch[13]
# Counter:0
# Accuracy : 	Training :    97.2580	 Test :    96.1000	 Hold out :    96.9200
# Loss     : 	Training :     0.0828	 Test :     0.1246	 Hold out :     0.0953
# Counter:80
# Accuracy : 	Training :    98.4580	 Test :    97.2200	 Hold out :    98.0300
# Loss     : 	Training :     0.0507	 Test :     0.0936	 Hold out :     0.0610
# Counter:160
# Accuracy : 	Training :    97.6880	 Test :    96.2700	 Hold out :    97.2200
# Loss     : 	Training :     0.0699	 Test :     0.1178	 Hold out :     0.0820
# Counter:240
# Accuracy : 	Training :    98.1120	 Test :    96.7000	 Hold out :    97.8100
# Loss     : 	Training :     0.0594	 Test :     0.1048	 Hold out :     0.0700
# Counter:320
# Accuracy : 	Training :    98.2520	 Test :    96.6300	 Hold out :    97.6200
# Loss     : 	Training :     0.0557	 Test :     0.1115	 Hold out :     0.0727
#
# Epoch[14]
# Counter:0
# Accuracy : 	Training :    98.0760	 Test :    96.7700	 Hold out :    98.2000
# Loss     : 	Training :     0.0627	 Test :     0.1097	 Hold out :     0.0605
# Counter:80
# Accuracy : 	Training :    98.2520	 Test :    96.9700	 Hold out :    98.0300
# Loss     : 	Training :     0.0582	 Test :     0.1002	 Hold out :     0.0622
# Counter:160
# Accuracy : 	Training :    98.6120	 Test :    97.1400	 Hold out :    98.4700
# Loss     : 	Training :     0.0466	 Test :     0.0950	 Hold out :     0.0522
# Counter:240
# Accuracy : 	Training :    98.2900	 Test :    96.8700	 Hold out :    98.1800
# Loss     : 	Training :     0.0553	 Test :     0.1032	 Hold out :     0.0600
# Counter:320
# Accuracy : 	Training :    98.3880	 Test :    96.9700	 Hold out :    98.0100
# Loss     : 	Training :     0.0525	 Test :     0.1025	 Hold out :     0.0635
#
# Epoch[15]
# Counter:0
# Accuracy : 	Training :    98.2520	 Test :    96.8600	 Hold out :    98.4500
# Loss     : 	Training :     0.0554	 Test :     0.1044	 Hold out :     0.0524
# Counter:80
# Accuracy : 	Training :    98.4580	 Test :    97.0300	 Hold out :    98.3200
# Loss     : 	Training :     0.0507	 Test :     0.0964	 Hold out :     0.0564
# Counter:160
# Accuracy : 	Training :    98.5960	 Test :    97.0400	 Hold out :    98.2900
# Loss     : 	Training :     0.0456	 Test :     0.0965	 Hold out :     0.0517
# Counter:240
# Accuracy : 	Training :    98.8360	 Test :    97.2000	 Hold out :    98.6700
# Loss     : 	Training :     0.0402	 Test :     0.0897	 Hold out :     0.0436
# Counter:320
# Accuracy : 	Training :    98.3600	 Test :    96.8600	 Hold out :    98.1000
# Loss     : 	Training :     0.0518	 Test :     0.1048	 Hold out :     0.0595
#
# Epoch[16]
# Counter:0
# Accuracy : 	Training :    98.2460	 Test :    96.8200	 Hold out :    98.2300
# Loss     : 	Training :     0.0531	 Test :     0.1018	 Hold out :     0.0552
# Counter:80
# Accuracy : 	Training :    98.6100	 Test :    97.0700	 Hold out :    98.4400
# Loss     : 	Training :     0.0461	 Test :     0.1001	 Hold out :     0.0510
# Counter:160
# Accuracy : 	Training :    98.7900	 Test :    97.0000	 Hold out :    98.5300
# Loss     : 	Training :     0.0400	 Test :     0.0944	 Hold out :     0.0463
# Counter:240
# Accuracy : 	Training :    98.7980	 Test :    97.2000	 Hold out :    98.5400
# Loss     : 	Training :     0.0407	 Test :     0.0920	 Hold out :     0.0506
# Counter:320
# Accuracy : 	Training :    98.7100	 Test :    96.9600	 Hold out :    98.4000
# Loss     : 	Training :     0.0425	 Test :     0.0966	 Hold out :     0.0503
#
# Epoch[17]
# Counter:0
# Accuracy : 	Training :    98.7420	 Test :    97.2700	 Hold out :    98.7800
# Loss     : 	Training :     0.0423	 Test :     0.0926	 Hold out :     0.0410
# Counter:80
# Accuracy : 	Training :    98.7740	 Test :    96.8500	 Hold out :    98.6900
# Loss     : 	Training :     0.0426	 Test :     0.0998	 Hold out :     0.0410
# Counter:160
# Accuracy : 	Training :    98.9960	 Test :    97.2600	 Hold out :    98.9600
# Loss     : 	Training :     0.0359	 Test :     0.0897	 Hold out :     0.0373
# Counter:240
# Accuracy : 	Training :    98.2980	 Test :    96.6700	 Hold out :    98.2500
# Loss     : 	Training :     0.0529	 Test :     0.1061	 Hold out :     0.0502
# Counter:320
# Accuracy : 	Training :    98.7060	 Test :    96.9700	 Hold out :    98.4900
# Loss     : 	Training :     0.0430	 Test :     0.0980	 Hold out :     0.0474
#
# Epoch[18]
# Counter:0
# Accuracy : 	Training :    98.4080	 Test :    96.8800	 Hold out :    98.5000
# Loss     : 	Training :     0.0518	 Test :     0.1044	 Hold out :     0.0524
# Counter:80
# Accuracy : 	Training :    98.9160	 Test :    97.2200	 Hold out :    98.8000
# Loss     : 	Training :     0.0362	 Test :     0.0903	 Hold out :     0.0381
# Counter:160
# Accuracy : 	Training :    98.5360	 Test :    96.9200	 Hold out :    98.4700
# Loss     : 	Training :     0.0458	 Test :     0.1064	 Hold out :     0.0464
# Counter:240
# Accuracy : 	Training :    98.7720	 Test :    96.9700	 Hold out :    98.6500
# Loss     : 	Training :     0.0405	 Test :     0.0985	 Hold out :     0.0445
# Counter:320
# Accuracy : 	Training :    98.8180	 Test :    97.0900	 Hold out :    98.6500
# Loss     : 	Training :     0.0383	 Test :     0.0943	 Hold out :     0.0448
#
# Epoch[19]
# Counter:0
# Accuracy : 	Training :    98.8440	 Test :    97.2600	 Hold out :    98.9900
# Loss     : 	Training :     0.0382	 Test :     0.0917	 Hold out :     0.0358
# Counter:80
# Accuracy : 	Training :    98.5840	 Test :    96.7100	 Hold out :    98.5300
# Loss     : 	Training :     0.0450	 Test :     0.1038	 Hold out :     0.0441
# Counter:160
# Accuracy : 	Training :    99.0540	 Test :    97.2600	 Hold out :    99.0700
# Loss     : 	Training :     0.0317	 Test :     0.0919	 Hold out :     0.0325
# Counter:240
# Accuracy : 	Training :    98.5980	 Test :    97.0900	 Hold out :    98.5400
# Loss     : 	Training :     0.0453	 Test :     0.0952	 Hold out :     0.0474
# Counter:320
# Accuracy : 	Training :    98.7040	 Test :    96.9700	 Hold out :    98.5400
# Loss     : 	Training :     0.0419	 Test :     0.0975	 Hold out :     0.0479
# Epoch[20]
# Counter:0
# Accuracy : 	Training :    99.0580	 Test :    97.2600	 Hold out :    98.8200
# Loss     : 	Training :     0.0335	 Test :     0.0876	 Hold out :     0.0357
# Counter:80
# Accuracy : 	Training :    98.2400	 Test :    96.7500	 Hold out :    98.1800
# Loss     : 	Training :     0.0520	 Test :     0.1056	 Hold out :     0.0562
# Counter:160
# Accuracy : 	Training :    98.8720	 Test :    97.0300	 Hold out :    98.7800
# Loss     : 	Training :     0.0366	 Test :     0.0997	 Hold out :     0.0426
# Counter:240
# Accuracy : 	Training :    99.0720	 Test :    97.3100	 Hold out :    98.8700
# Loss     : 	Training :     0.0312	 Test :     0.0883	 Hold out :     0.0382
# Counter:320
# Accuracy : 	Training :    98.9660	 Test :    97.1700	 Hold out :    98.6900
# Loss     : 	Training :     0.0336	 Test :     0.0964	 Hold out :     0.0421
#
# Epoch[21]
# Counter:0
# Accuracy : 	Training :    98.9620	 Test :    97.1700	 Hold out :    98.9100
# Loss     : 	Training :     0.0347	 Test :     0.0937	 Hold out :     0.0355
# Counter:80
# Accuracy : 	Training :    99.0020	 Test :    96.9800	 Hold out :    98.9500
# Loss     : 	Training :     0.0336	 Test :     0.0965	 Hold out :     0.0368
# Counter:160
# Accuracy : 	Training :    99.0660	 Test :    97.0700	 Hold out :    98.8800
# Loss     : 	Training :     0.0324	 Test :     0.0958	 Hold out :     0.0371
# Counter:240
# Accuracy : 	Training :    98.8940	 Test :    97.0700	 Hold out :    98.4800
# Loss     : 	Training :     0.0360	 Test :     0.0980	 Hold out :     0.0451
# Counter:320
# Accuracy : 	Training :    99.1520	 Test :    97.2500	 Hold out :    98.9900
# Loss     : 	Training :     0.0293	 Test :     0.0916	 Hold out :     0.0341
#
# Epoch[22]
# Counter:0
# Accuracy : 	Training :    99.0300	 Test :    97.2700	 Hold out :    99.2600
# Loss     : 	Training :     0.0324	 Test :     0.0941	 Hold out :     0.0286
# Counter:80
# Accuracy : 	Training :    99.1700	 Test :    97.2200	 Hold out :    99.1900
# Loss     : 	Training :     0.0287	 Test :     0.0907	 Hold out :     0.0292
# Counter:160
# Accuracy : 	Training :    99.0720	 Test :    96.9000	 Hold out :    98.8800
# Loss     : 	Training :     0.0313	 Test :     0.0992	 Hold out :     0.0343
# Counter:240
# Accuracy : 	Training :    98.9120	 Test :    97.2000	 Hold out :    98.7700
# Loss     : 	Training :     0.0363	 Test :     0.0982	 Hold out :     0.0390
# Counter:320
# Accuracy : 	Training :    99.0080	 Test :    97.3100	 Hold out :    98.8300
# Loss     : 	Training :     0.0327	 Test :     0.0918	 Hold out :     0.0359
#
# Epoch[23]
# Counter:0
# Accuracy : 	Training :    99.1140	 Test :    97.3800	 Hold out :    99.0800
# Loss     : 	Training :     0.0297	 Test :     0.0895	 Hold out :     0.0306
# Counter:80
# Accuracy : 	Training :    99.0920	 Test :    97.1700	 Hold out :    98.9800
# Loss     : 	Training :     0.0296	 Test :     0.0937	 Hold out :     0.0339
# Counter:160
# Accuracy : 	Training :    98.9880	 Test :    96.7900	 Hold out :    98.7000
# Loss     : 	Training :     0.0333	 Test :     0.1038	 Hold out :     0.0383
# Counter:240
# Accuracy : 	Training :    98.9700	 Test :    97.0200	 Hold out :    98.8300
# Loss     : 	Training :     0.0341	 Test :     0.0975	 Hold out :     0.0380
# Counter:320
# Accuracy : 	Training :    99.0040	 Test :    96.9800	 Hold out :    98.7700
# Loss     : 	Training :     0.0330	 Test :     0.1010	 Hold out :     0.0384
#
# Epoch[24]
# Counter:0
# Accuracy : 	Training :    98.6860	 Test :    96.7600	 Hold out :    98.7800
# Loss     : 	Training :     0.0415	 Test :     0.1114	 Hold out :     0.0380
# Counter:80
# Accuracy : 	Training :    99.1420	 Test :    97.1600	 Hold out :    99.0700
# Loss     : 	Training :     0.0294	 Test :     0.0932	 Hold out :     0.0293
# Counter:160
# Accuracy : 	Training :    99.2580	 Test :    97.3000	 Hold out :    99.1300
# Loss     : 	Training :     0.0269	 Test :     0.0902	 Hold out :     0.0289
# Counter:240
# Accuracy : 	Training :    99.2100	 Test :    97.2100	 Hold out :    99.2300
# Loss     : 	Training :     0.0266	 Test :     0.0924	 Hold out :     0.0273
# Counter:320
# Accuracy : 	Training :    98.7760	 Test :    96.7700	 Hold out :    98.6500
# Loss     : 	Training :     0.0379	 Test :     0.1056	 Hold out :     0.0413
#
# Epoch[25]
# Counter:0
# Accuracy : 	Training :    98.9980	 Test :    96.9600	 Hold out :    98.9700
# Loss     : 	Training :     0.0322	 Test :     0.1034	 Hold out :     0.0334
# Counter:80
# Accuracy : 	Training :    99.1300	 Test :    96.9500	 Hold out :    99.0800
# Loss     : 	Training :     0.0291	 Test :     0.1012	 Hold out :     0.0307
# Counter:160
# Accuracy : 	Training :    99.0980	 Test :    96.8800	 Hold out :    98.9500
# Loss     : 	Training :     0.0302	 Test :     0.1008	 Hold out :     0.0352
# Counter:240
# Accuracy : 	Training :    99.4220	 Test :    97.2300	 Hold out :    99.1100
# Loss     : 	Training :     0.0227	 Test :     0.0901	 Hold out :     0.0282
# Counter:320
# Accuracy : 	Training :    99.1780	 Test :    97.2100	 Hold out :    98.8800
# Loss     : 	Training :     0.0273	 Test :     0.0927	 Hold out :     0.0341
#
# Epoch[26]
# Counter:0
# Accuracy : 	Training :    99.2940	 Test :    97.2600	 Hold out :    99.3200
# Loss     : 	Training :     0.0252	 Test :     0.0928	 Hold out :     0.0225
# Counter:80
# Accuracy : 	Training :    98.8740	 Test :    96.9700	 Hold out :    98.9300
# Loss     : 	Training :     0.0354	 Test :     0.1049	 Hold out :     0.0332
# Counter:160
# Accuracy : 	Training :    99.2880	 Test :    97.1400	 Hold out :    99.2800
# Loss     : 	Training :     0.0268	 Test :     0.0948	 Hold out :     0.0246
# Counter:240
# Accuracy : 	Training :    99.3100	 Test :    97.2800	 Hold out :    99.2100
# Loss     : 	Training :     0.0243	 Test :     0.0911	 Hold out :     0.0242
# Counter:320
# Accuracy : 	Training :    99.3760	 Test :    97.2000	 Hold out :    99.2500
# Loss     : 	Training :     0.0226	 Test :     0.0945	 Hold out :     0.0248
#
# Epoch[27]
# Counter:0
# Accuracy : 	Training :    99.3560	 Test :    97.1400	 Hold out :    99.3200
# Loss     : 	Training :     0.0237	 Test :     0.0975	 Hold out :     0.0244
# Counter:80
# Accuracy : 	Training :    99.4640	 Test :    97.1500	 Hold out :    99.4600
# Loss     : 	Training :     0.0210	 Test :     0.0940	 Hold out :     0.0217
# Counter:160
# Accuracy : 	Training :    99.5200	 Test :    97.2500	 Hold out :    99.5100
# Loss     : 	Training :     0.0189	 Test :     0.0880	 Hold out :     0.0200
# Counter:240
# Accuracy : 	Training :    99.3460	 Test :    97.2500	 Hold out :    99.2000
# Loss     : 	Training :     0.0233	 Test :     0.0930	 Hold out :     0.0265
# Counter:320
# Accuracy : 	Training :    99.5160	 Test :    97.1200	 Hold out :    99.4200
# Loss     : 	Training :     0.0190	 Test :     0.0948	 Hold out :     0.0218
#
# Epoch[28]
# Counter:0
# Accuracy : 	Training :    99.3300	 Test :    97.3400	 Hold out :    99.3800
# Loss     : 	Training :     0.0237	 Test :     0.0943	 Hold out :     0.0235
# Counter:80
# Accuracy : 	Training :    99.5880	 Test :    97.3100	 Hold out :    99.5600
# Loss     : 	Training :     0.0169	 Test :     0.0909	 Hold out :     0.0188
# Counter:160
# Accuracy : 	Training :    99.3860	 Test :    97.2200	 Hold out :    99.3600
# Loss     : 	Training :     0.0215	 Test :     0.0954	 Hold out :     0.0243
# Counter:240
# Accuracy : 	Training :    99.4720	 Test :    97.0900	 Hold out :    99.2700
# Loss     : 	Training :     0.0201	 Test :     0.0994	 Hold out :     0.0247
# Counter:320
# Accuracy : 	Training :    99.3740	 Test :    97.2200	 Hold out :    99.2700
# Loss     : 	Training :     0.0225	 Test :     0.0933	 Hold out :     0.0275
#
# Epoch[29]
# Counter:0
# Accuracy : 	Training :    99.3920	 Test :    97.2700	 Hold out :    99.4600
# Loss     : 	Training :     0.0221	 Test :     0.0974	 Hold out :     0.0197
# Counter:80
# Accuracy : 	Training :    99.5400	 Test :    97.3200	 Hold out :    99.5000
# Loss     : 	Training :     0.0179	 Test :     0.0946	 Hold out :     0.0170
# Counter:160
# Accuracy : 	Training :    99.6400	 Test :    97.4800	 Hold out :    99.6400
# Loss     : 	Training :     0.0163	 Test :     0.0912	 Hold out :     0.0150
# Counter:240
# Accuracy : 	Training :    99.5960	 Test :    97.2800	 Hold out :    99.6000
# Loss     : 	Training :     0.0172	 Test :     0.0947	 Hold out :     0.0168
# Counter:320
# Accuracy : 	Training :    99.3660	 Test :    97.1500	 Hold out :    99.3400
# Loss     : 	Training :     0.0222	 Test :     0.0989	 Hold out :     0.0220

# %%
plt.figure
plt.plot(np.arange(0,len(net.records["loss"]["training"])),net.records["loss"]["training"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["test"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["hold_out"])
plt.gca().set_title("Loss over training")
plt.gca().legend(["Training","Test","Hold out"])
plt.xlabel("Training")
plt.ylabel("Loss")
plt.grid()
plt.savefig("./img/loss_5a_double",dpi=300)
plt.show()


plt.figure()
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])),net.records["accuracy"]["training"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["test"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["hold_out"])
plt.gca().set_title("Accuracy over training")
plt.gca().legend(["Training","Test","Hold out"])
plt.xlabel("Training")
plt.ylabel("Accuracy")
plt.gca().set_yticks([0,20,40,60,80,90,98])
plt.grid()
plt.savefig("./img/acc_5a_double",dpi=300)
plt.show()

# %%
import pickle
with open("./pickle_data/5a_double.dat","wb") as f:
    net.data = None
    pickle.dump(net, f)
