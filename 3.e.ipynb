# %%
from neural_network import *
from data_prep import *
import matplotlib.pyplot as plt




if __name__ == "__main__":

    net = Network(
        layers = [784,64,10],
        max_epoch = 15,
        eta = 0.01,
        func = 'sigmoid',
        is_sqrt_initialize = False,
        is_shuffle = True,
        momentum_type = None
    )
    training_images,training_labels,test_images,test_labels = data_prep()
    net.fit(training_images,training_labels,test_images,test_labels)
# Out:
# Epoch[0]
# Accuracy : 	Training :    11.3600	 Test :    11.3783	 Hold out :    11.4700
# Loss     : 	Training : 147700.0836	 Test : 177048.0499	 Hold out : 29347.9663
# Accuracy : 	Training :    47.6680	 Test :    47.6300	 Hold out :    47.4400
# Loss     : 	Training : 41204.1909	 Test : 49479.8585	 Hold out :  8275.6676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7ebb4058a69a> in <module>()
#      20     )
#      21     training_images,training_labels,test_images,test_labels = data_prep()
# ---> 22     net.fit(training_images,training_labels,test_images,test_labels)
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in fit(self, raw_images, raw_labels, test_images, test_labels)
#     188
#     189
# --> 190             self.train_with_mini_batch(training_images, training_labels)
#     191
#     192             del training_images
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in train_with_mini_batch(self, raw_images, raw_labels)
#     127
#     128             if counter % 30 ==0:
# --> 129                 self.show_result()
#     130
#     131             counter +=1
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in show_result(self)
#     229         training_accuracy, training_loss = self.check(training_images, training_labels)
#     230         test_accuracy, test_loss = self.check(test_images, test_labels)
# --> 231         hold_out_accuracy, hold_out_loss = self.check(hold_out_images, hold_out_labels)
#     232         print("Accuracy : \tTraining : %10.4f\t Test : %10.4f\t Hold out : %10.4f" % (
#     233             training_accuracy * 100, test_accuracy * 100, hold_out_accuracy * 100))
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in check(self, images, labels)
#     208
#     209     def check(self,images,labels):
# --> 210         raw_result = [self.test(images[:,i]) for i in range(labels.shape[1])]
#     211         result = np.array([np.argmax(x) for x in raw_result])
#     212         # result = np.array([np.argmax(self.test(images[:,i])) for i in range(labels.shape[1])])
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in <listcomp>(.0)
#     208
#     209     def check(self,images,labels):
# --> 210         raw_result = [self.test(images[:,i]) for i in range(labels.shape[1])]
#     211         result = np.array([np.argmax(x) for x in raw_result])
#     212         # result = np.array([np.argmax(self.test(images[:,i])) for i in range(labels.shape[1])])
#
# E:\UCSanDiego\Projects\CSE253\hw2\neural_network.py in test(self, input_data)
#     110
#     111     def test(self,input_data):
# --> 112         self.a[0] = np.array(input_data).reshape(self.a[0].shape)
#     113         self.feed_forward()
#     114         return self.a[-1].astype(float)
#
# KeyboardInterrupt:

# %%
plt.plot(np.arange(0,len(net.records["loss"]["training"])),net.records["loss"]["training"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["test"])
plt.plot(np.arange(0,len(net.records["loss"]["training"])), net.records["loss"]["hold_out"])
plt.show()

plt.plot(np.arange(0,len(net.records["accuracy"]["training"])),net.records["accuracy"]["training"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["test"])
plt.plot(np.arange(0,len(net.records["accuracy"]["training"])), net.records["accuracy"]["hold_out"])
plt.show()
